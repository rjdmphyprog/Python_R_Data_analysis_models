# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("all_data.csv", header = 0)
df.head(2)
# Out:
#     id  fci  hund  wamiz          woopets  chien  hund_identifiant  hund_id  \
# 0  194  1.0   1.0  259.0  pointer anglais    194               1.0      1.0
# 1   63  2.0   2.0  278.0   setter anglais     63               2.0      2.0
#
#          hund_name  hund_weight  ...  fci_date_es  fci_date_acceptance  \
# 0  pointer anglais         26.0  ...   28/10/2009                  0.0
# 1   setter anglais         27.5  ...   28/10/2009                  0.0
#
#              fci_groupe                               fci_section  \
# 0  n°7 - Chiens d'arrêt  Chiens d'arrêt britanniques et irlandais
# 1  n°7 - Chiens d'arrêt  Chiens d'arrêt britanniques et irlandais
#
#   fci_provisional                  fci_status      fci_country  \
# 0      05/03/1963  Reconnue à titre définitif  grande-bretagne
# 1      06/03/1963  Reconnue à titre définitif  grande-bretagne
#
#                                              fci_url  \
# 0  http://www.fci.be/fr/nomenclature/POINTER-ANGL...
# ...

# %%
df.shape
# Out:
# (489, 143)

# %%
df.columns
# Out:
# Index(['id', 'fci', 'hund', 'wamiz', 'woopets', 'chien', 'hund_identifiant',
#        'hund_id', 'hund_name', 'hund_weight',
#        ...
#        'fci_date_es', 'fci_date_acceptance', 'fci_groupe', 'fci_section',
#        'fci_provisional', 'fci_status', 'fci_country', 'fci_url', 'fci_image',
#        'fci_pdf'],
#       dtype='object', length=143)

# %%
df.describe()
# Out:
#                id         fci        hund       wamiz       chien  \
# count  489.000000  273.000000  272.000000   87.000000  489.000000
# mean   288.051125  177.025641  177.022059  126.919540  288.051125
# std    169.597026  103.611953  103.802926  102.737441  169.597026
# min      4.000000    1.000000    1.000000    1.000000    4.000000
# 25%    136.000000   92.000000   91.500000   44.000000  136.000000
# 50%    286.000000  176.000000  175.500000   87.000000  286.000000
# 75%    444.000000  267.000000  267.250000  210.500000  444.000000
# max    568.000000  357.000000  357.000000  320.000000  568.000000
#
#        hund_identifiant     hund_id  hund_weight  hund_height    hund_age  \
# count        266.000000  266.000000   266.000000   266.000000  266.000000
# mean         164.037594  174.443609    24.986842    51.887218   12.327068
# std           97.253484  101.674242    15.016306    13.930978    1.318297
# min            1.000000    1.000000     3.000000    22.000000    7.000000
# ...

# %%
ver = (df.count() / 489 > 0.6)

# %%
ver = pd.DataFrame(ver, columns = ["bool"])
ver
# Out:
#               bool
# id            True
# fci          False
# hund         False
# wamiz        False
# woopets      False
# ...            ...
# fci_status   False
# fci_country  False
# fci_url      False
# fci_image    False
# fci_pdf      False
#
# [143 rows x 1 columns]

# %%
sns.countplot(x = "bool", data = ver)
# Out:
# <AxesSubplot:xlabel='bool', ylabel='count'>

# %%
for index in ver.index:
    if ver.loc[index] == "False":
        del df[index]
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-ff43a3a8cb4c> in <module>
#       1 for index in ver.index:
# ----> 2     if ver.loc[index] == "False":
#       3         del df[index]
#       4 df
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1327
#    1328     def __nonzero__(self):
# -> 1329         raise ValueError(
#    1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
